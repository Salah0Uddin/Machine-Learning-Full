# %% [markdown]
# <a href="https://colab.research.google.com/github/Salah0Uddin/Machine-Learning-Full/blob/main/EDA_2_Autoviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install autoviz
# Out:
# Collecting autoviz
#   Downloading autoviz-0.1.905-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.11/dist-packages (from autoviz) (2.0.2)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (from autoviz) (1.9.4)
# Collecting emoji (from autoviz)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting pyamg (from autoviz)
#   Downloading pyamg-5.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from autoviz) (1.6.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from autoviz) (0.14.5)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from autoviz) (3.9.1)
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (from autoviz) (0.19.0)
# Collecting xgboost<1.7,>=0.82 (from autoviz)
#   Downloading xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: fsspec>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from autoviz) (2025.3.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from autoviz) (4.14.1)
# Collecting pandas-dq>=1.29 (from autoviz)
#   Downloading pandas_dq-1.29-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.11/dist-packages (from autoviz) (2.0.2)
# Collecting hvplot>=0.9.2 (from autoviz)
#   Downloading hvplot-0.11.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: holoviews>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from autoviz) (1.21.0)
# Requirement already satisfied: panel>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from autoviz) (1.7.3)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.11/dist-packages (from autoviz) (2.2.2)
# Requirement already satisfied: matplotlib>3.7.4 in /usr/local/lib/python3.11/dist-packages (from autoviz) (3.10.0)
# Requirement already satisfied: seaborn>0.12.2 in /usr/local/lib/python3.11/dist-packages (from autoviz) (0.13.2)
# Requirement already satisfied: bokeh>=3.1 in /usr/local/lib/python3.11/dist-packages (from holoviews>=1.16.0->autoviz) (3.7.3)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.11/dist-packages (from holoviews>=1.16.0->autoviz) (3.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from holoviews>=1.16.0->autoviz) (24.2)
# Requirement already satisfied: param<3.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from holoviews>=1.16.0->autoviz) (2.2.1)
# Requirement already satisfied: pyviz-comms>=2.1 in /usr/local/lib/python3.11/dist-packages (from holoviews>=1.16.0->autoviz) (3.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->autoviz) (2025.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (6.2.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (2.0.3)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (3.8.2)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (0.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from panel>=1.4.0->autoviz) (4.67.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->autoviz) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->autoviz) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->autoviz) (3.6.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->autoviz) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->autoviz) (2024.11.6)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->autoviz) (1.0.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.6)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (1.46.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.11/dist-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2025.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>3.7.4->autoviz) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.11/dist-packages (from linkify-it-py->panel>=1.4.0->autoviz) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py->panel>=1.4.0->autoviz) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->panel>=1.4.0->autoviz) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->panel>=1.4.0->autoviz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->panel>=1.4.0->autoviz) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->panel>=1.4.0->autoviz) (2025.7.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.0.2)
# Downloading autoviz-0.1.905-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 5.2 MB/s eta 0:00:00
# Downloading hvplot-0.11.3-py3-none-any.whl (170 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.3/170.3 kB 9.2 MB/s eta 0:00:00
# Downloading pandas_dq-1.29-py3-none-any.whl (29 kB)
# Downloading xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl (255.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 5.3 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 33.4 MB/s eta 0:00:00
# Downloading pyamg-5.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 66.5 MB/s eta 0:00:00
# Installing collected packages: emoji, xgboost, pyamg, pandas-dq, hvplot, autoviz
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.1.4
#     Uninstalling xgboost-2.1.4:
#       Successfully uninstalled xgboost-2.1.4
# Successfully installed autoviz-0.1.905 emoji-2.14.1 hvplot-0.11.3 pandas-dq-1.29 pyamg-5.2.1 xgboost-1.6.2

# %%
import seaborn as sns
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.to_csv('tips.csv')

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %%
AV=AutoViz_Class()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
filename='tips.csv'
sep=','
dft=AV.AutoViz(filename,sep=sep,depVar='')
# Out:
# Shape of your Data Set loaded: (244, 8)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     8 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Unnamed: 0']
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_e3a51_row0_col0, #T_e3a51_row0_col2, #T_e3a51_row0_col3, #T_e3a51_row0_col4, #T_e3a51_row0_col5, #T_e3a51_row1_col0, #T_e3a51_row1_col2, #T_e3a51_row1_col3, #T_e3a51_row1_col4, #T_e3a51_row1_col5, #T_e3a51_row2_col0, #T_e3a51_row2_col2, #T_e3a51_row2_col3, #T_e3a51_row2_col4, #T_e3a51_row2_col5, #T_e3a51_row3_col0, #T_e3a51_row3_col2, #T_e3a51_row3_col3, #T_e3a51_row3_col4, #T_e3a51_row3_col5, #T_e3a51_row4_col0, #T_e3a51_row4_col2, #T_e3a51_row4_col3, #T_e3a51_row4_col4, #T_e3a51_row4_col5, #T_e3a51_row5_col0, #T_e3a51_row5_col2, #T_e3a51_row5_col3, #T_e3a51_row5_col4, #T_e3a51_row5_col5, #T_e3a51_row6_col0, #T_e3a51_row6_col2, #T_e3a51_row6_col3, #T_e3a51_row6_col4, #T_e3a51_row6_col5, #T_e3a51_row7_col0, #T_e3a51_row7_col2, #T_e3a51_row7_col3, #T_e3a51_row7_col4, #T_e3a51_row7_col5 {
#   font-family: Segoe UI;
# }
# #T_e3a51_row0_col1, #T_e3a51_row1_col1, #T_e3a51_row2_col1, #T_e3a51_row3_col1, #T_e3a51_row4_col1, #T_e3a51_row5_col1, #T_e3a51_row6_col1, #T_e3a51_row7_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_e3a51" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3a51_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_e3a51_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_e3a51_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_e3a51_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_e3a51_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_e3a51_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3a51_level0_row0" class="row_heading level0 row0" >Unnamed: 0</th>
#       <td id="T_e3a51_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_e3a51_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_e3a51_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_e3a51_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_e3a51_row0_col4" class="data row0 col4" >243.000000</td>
#       <td id="T_e3a51_row0_col5" class="data row0 col5" >Possible ID column: drop before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_e3a51_level0_row1" class="row_heading level0 row1" >total_bill</th>
#       <td id="T_e3a51_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_e3a51_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_e3a51_row1_col2" class="data row1 col2" >NA</td>
#       <td id="T_e3a51_row1_col3" class="data row1 col3" >3.070000</td>
#       <td id="T_e3a51_row1_col4" class="data row1 col4" >50.810000</td>
#       <td id="T_e3a51_row1_col5" class="data row1 col5" >Column has 9 outliers greater than upper bound (40.30) or lower than lower bound(-2.82). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_e3a51_level0_row2" class="row_heading level0 row2" >tip</th>
#       <td id="T_e3a51_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_e3a51_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_e3a51_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_e3a51_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_e3a51_row2_col4" class="data row2 col4" >10.000000</td>
#       <td id="T_e3a51_row2_col5" class="data row2 col5" >Column has 9 outliers greater than upper bound (5.91) or lower than lower bound(-0.34). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_e3a51_level0_row3" class="row_heading level0 row3" >sex</th>
#       <td id="T_e3a51_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_e3a51_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_e3a51_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_e3a51_row3_col3" class="data row3 col3" ></td>
#       <td id="T_e3a51_row3_col4" class="data row3 col4" ></td>
#       <td id="T_e3a51_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_e3a51_level0_row4" class="row_heading level0 row4" >smoker</th>
#       <td id="T_e3a51_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_e3a51_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_e3a51_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_e3a51_row4_col3" class="data row4 col3" ></td>
#       <td id="T_e3a51_row4_col4" class="data row4 col4" ></td>
#       <td id="T_e3a51_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_e3a51_level0_row5" class="row_heading level0 row5" >day</th>
#       <td id="T_e3a51_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_e3a51_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_e3a51_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_e3a51_row5_col3" class="data row5 col3" ></td>
#       <td id="T_e3a51_row5_col4" class="data row5 col4" ></td>
#       <td id="T_e3a51_row5_col5" class="data row5 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_e3a51_level0_row6" class="row_heading level0 row6" >time</th>
#       <td id="T_e3a51_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_e3a51_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_e3a51_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_e3a51_row6_col3" class="data row6 col3" ></td>
#       <td id="T_e3a51_row6_col4" class="data row6 col4" ></td>
#       <td id="T_e3a51_row6_col5" class="data row6 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_e3a51_level0_row7" class="row_heading level0 row7" >size</th>
#       <td id="T_e3a51_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_e3a51_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_e3a51_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_e3a51_row7_col3" class="data row7 col3" >1.000000</td>
#       <td id="T_e3a51_row7_col4" class="data row7 col4" >6.000000</td>
#       <td id="T_e3a51_row7_col5" class="data row7 col5" >Column has 9 outliers greater than upper bound (4.50) or lower than lower bound(0.50). Cap them or remove them.</td>
#     </tr>
#   </tbody>
# </table>
# Number of All Scatter Plots = 3
# All Plots done
# Time to run AutoViz = 4 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
